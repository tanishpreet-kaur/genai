# %% [markdown]
# LLMChain

# %%
from langchain.chat_models import init_chat_model
from langchain_classic.chains import LLMChain
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
prompt = PromptTemplate(
    template = "Suggest a catchy blog about {topic}",
    input_variables = ["topic"]
)
chain = LLMChain(llm = model, prompt = prompt)
topic = input("Enter a topic: ")
output = chain.invoke(topic)
print("Generated Blog Title: ", output)
# Out:
# C:\Users\tanishpreet.k\AppData\Local\Temp\ipykernel_35804\3256316713.py:6: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use `RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm = model, prompt = prompt)
# Generated Blog Title:  {'topic': 'stars', 'text': "Here are some catchy blog title suggestions about stars, categorized for different vibes:\n\n**Intriguing & Mysterious:**\n\n*   The Cosmic Whisperer\n*   Secrets of the Starlight\n*   Beyond the Velvet Veil\n*   The Celestial Enigma\n*   Where the Stars Dream\n*   Echoes from the Abyss\n*   Stardust Chronicles\n*   The Unseen Universe\n*   Whispers from the Void\n*   A Glimpse of the Infinite\n\n**Wonder & Awe-Inspiring:**\n\n*   Lost in the Starlight\n*   Cosmic Canvas\n*   Adventures Among the Stars\n*   The Universe in a Glimmer\n*   Starlight Serenade\n*   Dancing with the Cosmos\n*   The Infinite Spark\n*   A Sky Full of Stories\n*   Where Wonder Takes Flight\n*   The Stellar Symphony\n\n**Informative & Educational (with a catchy twist):**\n\n*   Starstruck Science\n*   The Stellar Schoolhouse\n*   Decoding the Cosmos\n*   Your Guide to the Galaxy\n*   Unlocking the Universe\n*   The Star Navigator\n*   Cosmic Curiosity\n*   Beyond the Big Bang (and Other Star Stuff)\n*   The Stellar Scoop\n*   Astronomy Adventures for the Curious\n\n**Personal & Relatable:**\n\n*   My Stargazing Journal\n*   Under the Same Stars\n*   Finding My Light (in the Stars)\n*   A Little Bit of Stardust\n*   My Cosmic Connection\n*   Chasing Constellations\n*   The View from My Window (to the Stars)\n*   Stars, Stories, and Solitude\n*   When the Stars Align\n*   My Universe, My Way\n\n**Short & Punchy:**\n\n*   Stellar\n*   Cosmos\n*   Astro-Log\n*   Starry-Eyed\n*   Galaxy Gazing\n*   The Star Beat\n*   Cosmic Buzz\n*   Star Shine\n*   Skyward\n*   The Celestial Post\n\n**Tips for Choosing the Best Title:**\n\n*   **Consider your target audience:** Who are you trying to reach?\n*   **Reflect your blog's content:** What specific aspects of stars will you focus on?\n*   **Keep it memorable:** Easy to recall and share.\n*   **Check for availability:** Make sure the domain name and social media handles are available.\n*   **Say it out loud:** Does it roll off the tongue?\n\nGood luck with your stellar blog!"}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

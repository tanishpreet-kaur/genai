# %%
from google import genai
from dotenv import load_dotenv
from decouple import config

load_dotenv()


client = genai.Client(api_key=config("GOOGLE_API_KEY"))

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)

print(response.text)
# Out:
# AI analyzes massive data to find patterns and make predictions.

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
ans = model.invoke("What is the capital of France?")

# %%
ans.content
# Out:
# 'The capital of France is **Paris**.'

# %%
ans
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cb350-936a-7022-8bcb-c11bb9251acb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 8, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}})

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

parser.invoke(ans)
# Out:
# 'The capital of France is **Paris**.'

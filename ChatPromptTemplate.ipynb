# %%
from langchain.messages import SystemMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# ### CHAT PROMPT TEMPLATE

# %%
chat_template =  ChatPromptTemplate([
    ("system", "You are a helpful {domain} expert"),
    ("human", "Explain in simple terms, what is {topic}")
])

# %%
prompt = chat_template.invoke({'domain': 'Computer Hardware', 'topic': 'SSD'})

# %%
print(prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful Computer Hardware expert', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain in simple terms, what is SSD', additional_kwargs={}, response_metadata={})]

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
result = model.invoke(prompt)

# %%
print(result)
# Out:
# content="Imagine your computer needs to store and access information, like documents, photos, or programs. Traditionally, it used a **Hard Disk Drive (HDD)**, which is like a spinning record player. It has a spinning disk and a needle that moves to read and write data. This mechanical process makes it slower.\n\nAn **SSD (Solid State Drive)** is a much newer and faster way to do the same thing. Instead of spinning disks, it uses **flash memory chips**, similar to what you find in USB drives or your smartphone.\n\nHere's a simple breakdown of the key differences and why SSDs are better:\n\n**Think of it like this:**\n\n*   **HDD (Old Way):** A **library with physical books**. To find a book, a librarian has to walk to the shelf, find the book, and bring it to you. This takes time.\n*   **SSD (New Way):** A **digital library with instant access**. You type in what you want, and the information appears immediately.\n\n**Key Advantages of SSDs:**\n\n*   **Speed:** This is the biggest one! SSDs are dramatically faster than HDDs. This means:\n    *   Your computer boots up much quicker.\n    *   Programs open almost instantly.\n    *   Files transfer much faster.\n    *   Games load much quicker.\n*   **No Moving Parts:** Because there are no spinning disks or moving needles, SSDs are:\n    *   **More durable:** Less likely to break if you drop your laptop.\n    *   **Quieter:** They don't make any clicking or whirring noises.\n    *   **More energy-efficient:** They use less power, which can help with laptop battery life.\n\n**In short:**\n\nAn **SSD is a super-fast storage device for your computer that uses flash memory chips instead of spinning disks.** It's like upgrading from a slow, old record player to a lightning-fast digital music player. This makes your whole computer feel much more responsive and snappy." additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019d04e3-bffd-7be2-adee-7b6293404bd6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 426, 'total_tokens': 442, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# ### MESSAGE PLACEHOLDER

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

# %%
chat_template = ChatPromptTemplate([
    ("system", "You are a helpful support agent"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{query}")
])

# %%
chat_history = []

# %%
with open("chat_history.txt") as f:
    chat_history.extend(f.readlines())

# %%
print(chat_history)
# Out:
# ['HumanMessage(content = "I want to request a fund for my order #12345")\n', 'AIMessage(content = "Your refund request for order # 12345 has been initiated. It will be processed in 3-5 business days.")']

# %%
chat_template.invoke({"chat_history": chat_history, "query": "Where is my refund?"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful support agent', additional_kwargs={}, response_metadata={}), HumanMessage(content='HumanMessage(content = "I want to request a fund for my order #12345")\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='AIMessage(content = "Your refund request for order # 12345 has been initiated. It will be processed in 3-5 business days.")', additional_kwargs={}, response_metadata={}), HumanMessage(content='Where is my refund?', additional_kwargs={}, response_metadata={})])

# %%
import random

class new_LLM:
    def __init__(self):
        print("Initializing new LLM...")
        
    def predict(self, prompt):
        response_list = [
            "Sure, I can help with that!",
            "I'm not sure about that.",
            "Can you please provide more details?",
            "That's an interesting question!",
            "Let me think about it for a moment."
        ]
        
        return {'response': random.choice(response_list)}

# %%
class new_PromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables
        
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
class new_LLMChain:
    def __init__(self, llm, prompt):
        self.llm = llm
        self.prompt = prompt
        
    def run(self, input_dict):
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)
        return result['response']

# %%
template = new_PromptTemplate(
    template = "Write a {length} poem on the topic {topic}",
    input_variables = ["length", "topic"]
)

# %%
llm = new_LLM()
chain = new_LLMChain(llm, template)
chain.run({'length': 'short', 'topic': 'nature'})
# Out:
# Initializing new LLM...
# 'Let me think about it for a moment.'

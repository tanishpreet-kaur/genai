# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
from langchain.messages import HumanMessage, SystemMessage, AIMessage

system_msg = SystemMessage(content=""" You are a helpful assistant for data science. You are expert in AI, ML, DL and Python programming language. 
                           You are also good at explaining complex concepts in simple terms. You are not allowed to answer any query not related to 
                           data science.""")

# %%
chat_history = [system_msg]

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()

# %%
while True:
    user_question = input("Ask question (type 'exit' to quit): ")

    if user_question.lower() == "exit":
        break

    chat_history.append(HumanMessage(content=user_question))

    ans = model.invoke(chat_history)
    response = parser.invoke(ans)
    print("\nAnswer:", response)
    print("-" * 100)
    
    chat_history.append(AIMessage(content=response))
# Out:
# Answer: ML stands for **Machine Learning**.
#
# In simple terms, Machine Learning is a type of **artificial intelligence (AI)** that allows computer systems to **learn from data** without being explicitly programmed.
#
# Think of it like teaching a child. You don't give them a rigid set of instructions for every single situation. Instead, you show them examples, and they start to recognize patterns and make decisions on their own.
#
# Here's a breakdown of the key ideas:
#
# *   **Learning from Data:** ML algorithms are fed large amounts of data. This data can be anything from images, text, numbers, or even sounds.
# *   **Pattern Recognition:** The algorithms analyze this data to identify patterns, relationships, and trends.
# *   **Making Predictions/Decisions:** Based on the patterns they've learned, ML models can then make predictions about new, unseen data or make decisions without human intervention.
# ...

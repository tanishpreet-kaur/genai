# %%
from langchain.chat_models import init_chat_model
from langchain_core.output_parsers import StrOutputParser

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
parser = StrOutputParser()

# %% [markdown]
# ZERO-SHOT PROMPTING

# %%
prompt = """
Classify the text into neutral, negative or positive. 
Text: I think the vacation is okay.
Sentiment:
"""
result = model.invoke(prompt)
parser.invoke(result)
# Out:
# 'Neutral'

# %% [markdown]
# FEW-SHOT PROMPTING

# %%
prompt = """
A "whatpu" is a small, furry animal native to Tanzania. An example of a sentence that uses the word whatpu is:
We were traveling in Africa and we saw these very cute whatpus.
 
To do a "farduddle" means to jump up and down really fast. An example of a sentence that uses the word farduddle is:
"""
result = model.invoke(prompt)
parser.invoke(result)
# Out:
# 'The children were so excited to get ice cream that they started to farduddle.'

# %% [markdown]
# CHAIN-OF-THOUGHT PROMPTING

# %%
prompt = """
The odd numbers in this group add up to an even number: 4, 8, 9, 15, 12, 2, 1.
A: Adding all the odd numbers (9, 15, 1) gives 25. The answer is False.
The odd numbers in this group add up to an even number: 17,  10, 19, 4, 8, 12, 24.
A: Adding all the odd numbers (17, 19) gives 36. The answer is True.
The odd numbers in this group add up to an even number: 16,  11, 14, 4, 8, 13, 24.
A: Adding all the odd numbers (11, 13) gives 24. The answer is True.
The odd numbers in this group add up to an even number: 17,  9, 10, 12, 13, 4, 2.
A: Adding all the odd numbers (17, 9, 13) gives 39. The answer is False.
The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1. 
A:
"""
result = model.invoke(prompt)
parser.invoke(result)
# Out:
# 'Adding all the odd numbers (15, 5, 13, 7, 1) gives 41. The answer is False.'

# %% [markdown]
# ZERO-SHOT CoT

# %%
prompt = """
I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman. I then went and bought 5 more apples and ate 1. How many apples did I remain with?
Let's think step by step.
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# Here's how to solve this step-by-step:
#
# 1.  **Start with the initial purchase:** You bought 10 apples.
#     *   Current apples: 10
#
# 2.  **Give apples to the neighbor:** You gave away 2 apples.
#     *   10 - 2 = 8
#     *   Current apples: 8
#
# 3.  **Give apples to the repairman:** You gave away another 2 apples.
#     *   8 - 2 = 6
#     *   Current apples: 6
#
# 4.  **Buy more apples:** You bought 5 more apples.
#     *   6 + 5 = 11
#     *   Current apples: 11
#
# 5.  **Eat an apple:** You ate 1 apple.
#     *   11 - 1 = 10
#     *   Current apples: 10
#
# You remained with **10** apples.

# %% [markdown]
# Auto-CoT

# %%
prompt = """
Q1: If a train travels 60 km in 1 hour, how far will it travel in 3 hours?
A1: Let's think step by step.
- Speed = 60 km/hour
- Time = 3 hours
- Distance = Speed × Time = 60 × 3 = 180 km
Answer: 180 km

Q2: A shop sells 5 apples for ₹50. What is the cost of 1 apple?
A2: Let's think step by step.
- 5 apples cost ₹50
- Cost of 1 apple = 50 ÷ 5 = ₹10
Answer: ₹10

Q3: A car travels 80 km in 2 hours. What is its speed per hour?
A3:
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# Let's think step by step.
# - Distance = 80 km
# - Time = 2 hours
# - Speed = Distance ÷ Time = 80 ÷ 2 = 40 km/hour
# Answer: 40 km/hour

# %% [markdown]
# META-PROMPTING

# %%
prompt = """
You are an expert prompt engineer. Your task is to improve and expand the following prompt so that it produces a high-quality, detailed, and structured output.

Original Prompt:
"Write a blog about Artificial Intelligence"

Instructions:
- Make the prompt more specific and detailed
- Define the target audience
- Specify tone and writing style
- Include structure (introduction, sections, conclusion)
- Add any constraints (length, examples, etc.)
- Ensure the prompt is reusable

Return:
1. Improved Prompt
2. Explanation of improvements
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# Here's the improved prompt and an explanation of the changes:
#
# ## 1. Improved Prompt
#
# ```prompt
# **Role:** You are an expert AI communicator and content creator, tasked with demystifying complex technological concepts for a general audience.
#
# **Task:** Write a comprehensive and engaging blog post exploring the multifaceted world of Artificial Intelligence (AI).
#
# **Target Audience:** Curious individuals with little to no prior technical knowledge of AI. They are interested in understanding what AI is, its current applications, its potential impact on society, and the ethical considerations surrounding it. They are likely to be readers of general interest technology blogs, news articles about AI, or those seeking to understand its relevance in their daily lives.
#
# **Tone and Writing Style:**
# *   **Tone:** Informative, accessible, optimistic yet balanced, and slightly awe-inspiring. Avoid overly technical jargon.
# *   **Writing Style:** Conversational, engaging, and storytelling. Use analogies and relatable examples. Employ clear, concise sentences and paragraphs. Maintain a positive outlook on AI's potential while acknowledging potential challenges.
#
# **Structure:** The blog post should follow a clear and logical structure:
#
# 1.  **Catchy Title:** A title that sparks curiosity and accurately reflects the content.
# 2.  **Introduction (approx. 150-200 words):**
#     *   Hook the reader with a compelling question or statement about AI.
#     *   Briefly define AI in simple terms, avoiding jargon.
#     *   State the blog post's purpose: to explore AI's impact and potential.
#     *   Provide a roadmap of what the reader will learn.
# 3.  **Section 1: What Exactly is Artificial Intelligence? (approx. 250-300 words):**
#     *   Break down AI into understandable concepts (e.g., machine learning, deep learning, neural networks – explain these simply with analogies).
#     *   Distinguish between Narrow AI (ANI), General AI (AGI), and Super AI (ASI) with brief explanations and examples.
#     *   Emphasize that current AI is primarily Narrow AI.
# 4.  **Section 2: AI in Action: Real-World Applications You're Already Using (approx. 300-400 words):**
#     *   Showcase diverse and relatable examples of AI in everyday life.
#     *   Examples: Virtual assistants (Siri, Alexa), recommendation engines (Netflix, Amazon), spam filters, fraud detection, self-driving car technology (mention its current limitations), medical diagnostics, personalized learning platforms.
#     *   For each example, briefly explain *how* AI is being used.
# 5.  **Section 3: The Future is Now: AI's Potential to Transform Our World (approx. 350-450 words):**
#     *   Explore exciting future possibilities and potential benefits.
#     *   Examples: Revolutionizing healthcare (drug discovery, personalized treatments), addressing climate change (optimizing energy grids, predicting weather patterns), enhancing education, boosting productivity in industries, creative AI (art, music).
#     *   Maintain an optimistic but grounded perspective.
# 6.  **Section 4: Navigating the Ethical Landscape: Challenges and Considerations (approx. 300-400 words):**
#     *   Address crucial ethical concerns in a balanced manner.
#     *   Topics: Job displacement, bias in AI algorithms (explain with a simple analogy), privacy concerns, security risks, the importance of transparency and accountability.
#     *   Frame these as challenges to be managed, not insurmountable obstacles.
# 7.  **Conclusion (approx. 150-200 words):**
#     *   Summarize the key takeaways.
#     *   Reiterate the transformative power of AI.
#     *   End with a thought-provoking statement or a call to action (e.g., encourage continued learning, engage in discussions about AI's future).
#
# **Constraints:**
# *   **Length:** Approximately 1500-2000 words.
# *   **Examples:** Use at least 5 distinct real-world examples in Section 2 and at least 3 distinct future potential examples in Section 3.
# *   **Jargon:** Minimize technical jargon. When a technical term is necessary, explain it immediately in simple language or using an analogy.
# *   **Originality:** Content should be original and not plagiarized.
#
# **Output Format:** A well-formatted blog post with clear headings for each section and subheadings where appropriate.
#
# **Reusability:** This prompt can be reused to generate blog posts on AI for different audiences by adjusting the "Target Audience" and "Tone and Writing Style" sections. For example, for a more technical audience, one could specify a more in-depth explanation of algorithms and machine learning techniques.
# ```
#
# ## 2. Explanation of Improvements
#
# The original prompt, "Write a blog about Artificial Intelligence," is extremely broad and lacks any direction. The improved prompt addresses this by incorporating several key elements crucial for generating high-quality, structured content:
#
# 1.  **Role Definition:**
#     *   **Improvement:** Added a "Role" to the prompt, assigning the AI the persona of an "expert AI communicator and content creator."
#     *   **Reasoning:** This helps the AI understand the desired perspective and expertise it should embody, leading to more authoritative and nuanced content.
#
# 2.  **Specificity and Detail:**
#     *   **Improvement:** The original prompt was a single sentence. The improved prompt breaks down the task into clear components, defining the subject matter in detail.
#     *   **Reasoning:** By specifying *what* aspects of AI to cover (definition, applications, future, ethics), the AI has a clear scope and knows what information to gather and present.
#
# 3.  **Target Audience Definition:**
#     *   **Improvement:** Explicitly defined the "Target Audience" as "curious individuals with little to no prior technical knowledge."
#     *   **Reasoning:** This is critical for tailoring the language, complexity, and examples. The AI now knows to avoid jargon and use relatable analogies, ensuring the content is accessible and engaging for the intended reader.
#
# 4.  **Tone and Writing Style Specification:**
#     *   **Improvement:** Detailed "Tone and Writing Style" guidelines were provided (informative, accessible, optimistic yet balanced, conversational, storytelling, etc.).
#     *   **Reasoning:** This ensures the blog post has a consistent voice and feel. It guides the AI to write in a way that resonates with the target audience and achieves the desired impact (e.g., making AI seem less intimidating and more fascinating).
#
# 5.  **Structure Inclusion:**
#     *   **Improvement:** A detailed, multi-point "Structure" was outlined, including specific word count suggestions for each section and clear objectives for each part (introduction, definition, applications, future, ethics, conclusion).
#     *   **Reasoning:** This provides a blueprint for the blog post, ensuring a logical flow, comprehensive coverage, and a well-organized final output. It prevents the AI from just randomly generating text and instead guides it to build a coherent narrative.
#
# 6.  **Constraint Addition:**
#     *   **Improvement:** Specific "Constraints" were added, such as approximate word count, minimum number of examples, and a directive to minimize jargon with explanations.
#     *   **Reasoning:** Constraints help control the output's quality and format. The word count ensures adequate depth, the example requirement grounds the abstract concepts, and the jargon rule reinforces accessibility.
#
# 7.  **Output Format Specification:**
#     *   **Improvement:** Specified the "Output Format" as a "well-formatted blog post with clear headings."
#     *   **Reasoning:** This ensures the generated text is presented in a way that is immediately recognizable and usable as a blog post.
#
# 8.  **Reusability Feature:**
#     *   **Improvement:** Added a dedicated section on "Reusability," explaining *how* the prompt can be adapted for different contexts.
#     *   **Reasoning:** This fulfills the requirement for a reusable prompt. By highlighting which sections can be modified (e.g., target audience, tone), it empowers users to generate variations of the blog post without starting from scratch, making the prompt a valuable tool.
#
# In essence, the improved prompt transforms a vague request into a precise set of instructions, guiding the AI to produce a high-quality, targeted, and well-structured piece of content that meets specific requirements.

# %% [markdown]
# SELF-CONSISTENCY

# %%
prompt = """
Q: There are 15 trees in the grove. Grove workers will plant trees in the grove today. After they are done,
there will be 21 trees. How many trees did the grove workers plant today?
A: We start with 15 trees. Later we have 21 trees. The difference must be the number of trees they planted.
So, they must have planted 21 - 15 = 6 trees. The answer is 6.

Q: If there are 3 cars in the parking lot and 2 more cars arrive, how many cars are in the parking lot?
A: There are 3 cars in the parking lot already. 2 more arrive. Now there are 3 + 2 = 5 cars. The answer is 5.

Q: Leah had 32 chocolates and her sister had 42. If they ate 35, how many pieces do they have left in total?
A: Leah had 32 chocolates and Leah’s sister had 42. That means there were originally 32 + 42 = 74
chocolates. 35 have been eaten. So in total they still have 74 - 35 = 39 chocolates. The answer is 39.

Q: Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many
golf balls did he have at the end of wednesday?
A: Michael initially had 58 balls. He lost 23 on Tuesday, so after that he has 58 - 23 = 35 balls. On
Wednesday he lost 2 more so now he has 35 - 2 = 33 balls. The answer is 33.

Q: Olivia has $23. She bought five bagels for $3 each. How much money does she have left?
A: She bought 5 bagels for $3 each. This means she spent $15. She has $8 left.

Q: When I was 6 my sister was half my age. Now I’m 70 how old is my sister?
A:
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# When you were 6 years old, your sister was half your age, which means she was 6 / 2 = 3 years old.
# This means your sister is 6 - 3 = 3 years younger than you.
# Since you are now 70 years old, your sister is 70 - 3 = 67 years old.
# The answer is 67.

# %% [markdown]
# GENERATED-KNOWLEDGE PROMPTING

# %%
prompt = """
Question: Part of golf is trying to get a higher point total than others. Yes or No?
Knowledge: The objective of golf is to play a set of holes in the least number of strokes. A round of golf typically consists of 18 holes. Each hole is played once in the round on a standard golf course. Each stroke is counted as one point, and the total number of strokes is used to determine the winner of the game.
Explain and Answer: 
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# **Explanation:**
#
# The provided knowledge states that "Each stroke is counted as one point, and the total number of strokes is used to determine the winner of the game." It also explicitly says, "The objective of golf is to play a set of holes in the least number of strokes." This means the *lower* your score (number of strokes) the better. Therefore, a *higher* point total (meaning more strokes) would result in a *lower* ranking, not a higher one.
#
# **Answer:**
#
# No

# %% [markdown]
# PROMPT-CHAINING

# %%
prompt = """
Extract positive and negative points from this review: "The phone is fast but battery life is poor."
Based on the points below, classify sentiment as Positive, Negative, or Mixed: [Extracted points]
Explain the sentiment classification:
Sentiment: [Result]
Points: [Extracted points]
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# Sentiment: Mixed
# Points:
# *   **Positive:** The phone is fast.
# *   **Negative:** Battery life is poor.
#
# **Explanation:** The review contains both a positive aspect (speed) and a negative aspect (battery life) of the phone. This combination of positive and negative feedback leads to a "Mixed" sentiment classification.

# %% [markdown]
# TREE-OF-THOUGHTS

# %%
prompt = """
Generate 3 different strategies to improve a business.

For each strategy:
- Explain steps
- List pros and cons

Then:
- Compare all strategies
- Select the best one
- Give final answer
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# Here are three different strategies to improve a business, along with their explanations, pros, cons, a comparison, and a final selection.
#
# ## Strategy 1: Enhance Customer Experience Through Personalization
#
# This strategy focuses on making each customer interaction as relevant and valuable as possible, fostering loyalty and driving repeat business.
#
# **Steps:**
#
# 1.  **Data Collection and Analysis:** Implement systems to gather customer data (purchase history, browsing behavior, demographics, feedback). Analyze this data to identify customer segments and individual preferences.
# 2.  **Personalized Communication:** Tailor marketing messages, email campaigns, and website content based on individual customer profiles. This could include personalized product recommendations, birthday discounts, or content relevant to their interests.
# 3.  **Personalized Product/Service Offerings:** Develop or customize products and services to meet specific customer needs. This might involve offering different service tiers, allowing for customization options, or creating bespoke solutions.
# 4.  **Proactive Customer Support:** Equip customer service teams with access to customer history and preferences to provide faster, more informed, and empathetic support. Implement proactive outreach for potential issues or to offer assistance.
# 5.  **Feedback Loop Integration:** Continuously collect customer feedback (surveys, reviews, social media monitoring) and use it to refine personalization efforts and improve the overall customer journey.
#
# **Pros:**
#
# *   **Increased Customer Loyalty:** Customers feel valued and understood, leading to stronger relationships and reduced churn.
# *   **Higher Conversion Rates:** Personalized recommendations and offers are more likely to resonate with customers, leading to more purchases.
# *   **Improved Customer Lifetime Value:** Loyal customers tend to spend more over time.
# *   **Competitive Differentiation:** In crowded markets, a superior personalized experience can set a business apart.
# *   **Valuable Insights:** Data collected for personalization provides deep insights into customer behavior and preferences, informing other business decisions.
#
# **Cons:**
#
# *   **Data Privacy Concerns:** Robust data security and transparent privacy policies are crucial to build trust and avoid backlash.
# *   **Implementation Complexity:** Requires investment in technology, data management, and staff training.
# *   **Potential for Over-Personalization:** Can feel intrusive or creepy if not handled carefully.
# *   **Cost of Technology and Expertise:** Sophisticated personalization tools and skilled personnel can be expensive.
# *   **Requires Ongoing Maintenance:** Personalization efforts need continuous monitoring, analysis, and adjustment.
#
# ## Strategy 2: Streamline Operations Through Technology Adoption
#
# This strategy aims to improve efficiency, reduce costs, and enhance productivity by integrating new technologies into core business processes.
#
# **Steps:**
#
# 1.  **Process Audit and Bottleneck Identification:** Analyze existing operational workflows to pinpoint inefficiencies, manual tasks, and areas where time or resources are wasted.
# 2.  **Technology Research and Selection:** Identify relevant technologies that can address identified bottlenecks. This could include CRM systems, ERP software, automation tools, project management software, or cloud-based solutions.
# 3.  **Pilot Testing and Integration:** Implement chosen technologies in a controlled environment or for specific departments to test their effectiveness and identify any integration challenges.
# 4.  **Employee Training and Change Management:** Provide comprehensive training to employees on how to use the new technologies. Manage the transition effectively to minimize resistance and ensure adoption.
# 5.  **Continuous Monitoring and Optimization:** Track the impact of new technologies on key performance indicators (KPIs) such as cost reduction, time savings, and error rates. Continuously refine processes and technology usage for optimal results.
#
# **Pros:**
#
# *   **Increased Efficiency and Productivity:** Automation and streamlined processes lead to faster task completion and higher output.
# *   **Reduced Operational Costs:** Minimizing manual labor, errors, and waste can significantly lower expenses.
# *   **Improved Accuracy and Consistency:** Technology can reduce human error and ensure consistent quality of output.
# *   **Enhanced Scalability:** Well-integrated technology can support business growth without a proportional increase in resources.
# *   **Better Data Management and Reporting:** Centralized systems provide clearer insights and facilitate data-driven decision-making.
#
# **Cons:**
#
# *   **High Upfront Investment:** The cost of software, hardware, and implementation can be substantial.
# *   **Resistance to Change:** Employees may be hesitant to adopt new technologies, requiring strong change management.
# *   **Technical Glitches and Downtime:** Reliance on technology means potential disruptions due to system failures or maintenance.
# *   **Need for Skilled IT Support:** Requires internal or external IT expertise to manage, maintain, and troubleshoot systems.
# *   **Risk of Choosing the Wrong Technology:** Inadequate research or poor selection can lead to wasted investment and unmet expectations.
#
# ## Strategy 3: Expand Market Reach Through Strategic Partnerships
#
# This strategy focuses on leveraging the strengths and customer bases of other businesses to access new markets and customer segments.
#
# **Steps:**
#
# 1.  **Identify Potential Partners:** Research businesses that complement your offerings, target similar but not identical customer segments, or have a presence in markets you wish to enter. Look for companies with a strong reputation and shared values.
# 2.  **Define Partnership Goals and Value Proposition:** Clearly articulate what each party stands to gain from the partnership. This could include joint marketing campaigns, co-branded products, cross-promotion, or distribution agreements.
# 3.  **Develop Partnership Agreements:** Formalize the terms of the collaboration, including responsibilities, revenue sharing, intellectual property, and exit strategies, through legally binding contracts.
# 4.  **Execute Joint Initiatives:** Launch collaborative projects, marketing campaigns, or product integrations as agreed upon. Ensure clear communication and coordination between partner teams.
# 5.  **Measure and Evaluate Partnership Performance:** Track the success of the partnership against defined goals and KPIs. Regularly review the relationship and make adjustments as needed.
#
# **Pros:**
#
# *   **Access to New Customer Bases:** Immediately tap into the existing customer network of your partners.
# *   **Reduced Marketing Costs:** Share the burden of marketing and customer acquisition with partners.
# *   **Enhanced Brand Credibility:** Associating with reputable partners can boost your own brand's image.
# *   **Faster Market Entry:** Leverage partners' established presence to enter new geographical or industry markets more quickly.
# *   **Innovation and New Product Development:** Collaboration can lead to the creation of new products or services that neither company could develop alone.
#
# **Cons:**
#
# *   **Loss of Control:** You are sharing decision-making power and are dependent on your partner's actions.
# *   **Brand Dilution Risk:** If the partner has a poor reputation or their brand doesn't align, it can negatively impact your own.
# *   **Conflicting Goals or Cultures:** Disagreements between partners on objectives, strategies, or operational styles can derail the collaboration.
# *   **Revenue Sharing and Profitability:** The need to share revenue can reduce individual profit margins.
# *   **Complexity of Management:** Managing relationships and ensuring seamless execution with external entities can be challenging.
#
# ---
#
# ## Comparison of Strategies
#
# | Feature             | Strategy 1: Customer Experience | Strategy 2: Technology Adoption | Strategy 3: Strategic Partnerships |
# | :------------------ | :------------------------------ | :------------------------------ | :--------------------------------- |
# | **Primary Focus**   | Customer Loyalty & Retention    | Efficiency & Cost Reduction     | Market Expansion & Reach           |
# | **Investment Type** | Data, CRM, Training             | Software, Hardware, IT Support  | Legal, Marketing, Relationship Mgmt |
# | **Risk Level**      | Moderate (Data Privacy)         | High (Implementation, Cost)     | Moderate to High (Partner Dependency) |
# | **Time to Impact**  | Medium to Long                  | Medium to Long                  | Medium to Long                     |
# | **Scalability**     | High (with data)                | High                            | Moderate to High                   |
# | **Direct Revenue Impact** | High (via conversion & LTV)     | Indirect (via cost savings)     | High (via new customers)           |
# | **Customer Facing** | Very High                       | Indirect                        | High                               |
# | **Internal Focus**  | Moderate                        | Very High                       | Moderate                           |
#
# ---
#
# ## Selection of the Best Strategy
#
# The "best" strategy is highly dependent on a business's current situation, goals, and industry. However, considering the long-term health and competitive advantage of most businesses, **Strategy 1: Enhance Customer Experience Through Personalization** often presents the most compelling and sustainable path to improvement.
#
# **Reasoning:**
#
# *   **Sustainable Competitive Advantage:** In today's market, products and services can often be replicated. However, a deeply ingrained culture of exceptional and personalized customer experience is much harder for competitors to copy.
# *   **Direct Impact on Revenue:** While cost savings from technology are valuable, a focus on customer experience directly drives sales through increased conversion rates and higher customer lifetime value. Loyal customers are also less price-sensitive.
# *   **Adaptability and Future-Proofing:** As customer expectations evolve, a business that is adept at understanding and personalizing its interactions will be better positioned to adapt to future trends and technological shifts.
# *   **Synergy with Other Strategies:** Personalization efforts often benefit from the data and efficiency gains provided by technology adoption (Strategy 2). Furthermore, personalized outreach can make strategic partnerships (Strategy 3) more impactful by ensuring targeted messaging to new customer segments.
# *   **Mitigation of Downsides:** While data privacy is a concern, it's a manageable one with proper implementation and transparency. The cost of technology can be phased in, and the rewards of increased loyalty often outweigh the initial investment.
#
# While Strategy 2 offers significant operational benefits and Strategy 3 can unlock rapid growth, they are often tactical improvements. Strategy 1 addresses the core of customer relationships, which is fundamental to long-term business success and resilience.
#
# ---
#
# ## Final Answer
#
# For a comprehensive and sustainable improvement, the **best strategy is to Enhance Customer Experience Through Personalization.** This approach not only drives immediate revenue through increased conversions and loyalty but also builds a defensible competitive advantage that is difficult for rivals to replicate. By making customers feel understood and valued, businesses can foster deeper relationships, leading to higher customer lifetime value and a more resilient brand. While this strategy requires investment in data and technology, its long-term impact on customer retention and revenue makes it the most strategic choice for overall business improvement.

# %% [markdown]
# AUTOMATIC REASONING AND TOOL-USE

# %%
prompt = """
You are an intelligent assistant that can reason step by step and use tools when needed.

Instructions:
- Break the problem into steps
- Use Python for calculations
- Show intermediate results

Problem:
Find the average of the squares of the numbers 3, 5, and 7.
"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
# Out:
# The problem asks us to find the average of the squares of the numbers 3, 5, and 7.
#
# Here's a step-by-step approach to solve this problem:
#
# **Step 1: Square each of the given numbers.**
# We need to calculate $3^2$, $5^2$, and $7^2$.
#
# **Step 2: Sum the squares of the numbers.**
# After calculating the squares, we will add them together.
#
# **Step 3: Calculate the average of the squares.**
# To find the average, we will divide the sum of the squares by the total count of numbers, which is 3 in this case.
#
# Let's perform the calculations using Python.
#
# **Step 1: Square each of the given numbers.**
#
# ```python
# num1 = 3
# num2 = 5
# num3 = 7
#
# square1 = num1**2
# square2 = num2**2
# square3 = num3**2
#
# print(f"The square of {num1} is: {square1}")
# print(f"The square of {num2} is: {square2}")
# print(f"The square of {num3} is: {square3}")
# ```
#
# **Intermediate Result 1:**
# The square of 3 is: 9
# The square of 5 is: 25
# The square of 7 is: 49
#
# **Step 2: Sum the squares of the numbers.**
#
# ```python
# sum_of_squares = square1 + square2 + square3
# print(f"The sum of the squares is: {sum_of_squares}")
# ```
#
# **Intermediate Result 2:**
# The sum of the squares is: 83
#
# **Step 3: Calculate the average of the squares.**
#
# ```python
# count = 3
# average_of_squares = sum_of_squares / count
# print(f"The average of the squares is: {average_of_squares}")
# ```
#
# **Final Result:**
# The average of the squares is: 27.666666666666668
#
# The final answer is $\boxed{27.666666666666668}$.

# %%
prompt = """

"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)

# %%
prompt = """

"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)

# %%
prompt = """

"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)

# %%
prompt = """

"""
result = model.invoke(prompt)
ans = parser.invoke(result)
print(ans)
